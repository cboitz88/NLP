# %%
import os
import pandas as pd
import nltk
# %matplotlib inline

# %%
# Initial imports
import os
from path import Path
import pandas as pd
from newsapi import NewsApiClient
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

get_ipython().run_line_magic("matplotlib", "inline")

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download("vader_lexicon")
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\boitz\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# # News Headlines Sentiment
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Read your api key environment variable
api_key = os.getenv("news_api")

# %%
# Create a newsapi client
from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch all the news about Bitcoin
bitcoin_headlines = newsapi.get_everything(
    q="bitcoin",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# Print total articles
print(f"Total articles about Bitcoin: {bitcoin_headlines['totalResults']}")
# Out:
# Total articles about Bitcoin: 4434

# %%
# Fetch all the news about Ethereum
ethereum_headlines = newsapi.get_everything(
    q="ethereum",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# Print total articles
print(f"Total articles about Ethereum: {ethereum_headlines['totalResults']}")
# Out:
# Total articles about Ethereum: 938

# %%
def create_df(news, language):
    articles = []
    for article in news:
        try:
            title = article["title"]
            description = article["description"]
            text = article["content"]
            date = article["publishedAt"][:10]

            articles.append({
                "title": title,
                "description": description,
                "text": text,
                "date": date,
                "language": language
            })
        except AttributeError:
            pass

    return pd.DataFrame(articles)
bitcoin_df = create_df(bitcoin_headlines["articles"], "en")
ethereum_df =create_df(ethereum_headlines["articles"], "en")

# %%
# Create the Bitcoin sentiment scores DataFrame

bitcoin_sentiments = []

for article in bitcoin_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
bitcoin_df = bitcoin_df[cols]

bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2019-11-03  Less than two miles from Icelands Reykjavik ai...   -0.1531
# 1  2019-11-20  Whether Bitcoin, an immaterial resource derive...    0.2999
# 2  2019-11-01  High school students in France may be among th...    0.0000
# 3  2019-10-27  Our robot colleague Satoshi Nakaboto writes ab...    0.5070
# 4  2019-11-08  Our robot colleague Satoshi Nakaboto writes ab...    0.5070
#
#    positive  negative  neutral
# 0     0.000     0.039    0.961
# 1     0.104     0.100    0.796
# 2     0.000     0.000    1.000
# 3     0.069     0.000    0.931
# 4     0.067     0.000    0.933

# %%
# Create the ethereum sentiment scores DataFrame


ethereum_sentiments = []

for article in ethereum_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
ethereum_df = ethereum_df[cols]

ethereum_df.head()
# Out:
#          date                                               text  compound  \
# 0  2019-11-20  Sharding and scalability. Transactions per sec...    0.3595
# 1  2019-10-24  Disrupt Berlin is right around the corner. And...    0.6249
# 2  2019-10-23  he plaBy now, you should almost certainly know...    0.4601
# 3  2019-11-01  Blockchain has been picking up the pace since ...   -0.3089
# 4  2019-10-23  Reuters\r\n<ul><li>Bitcoin slumped as much as ...   -0.3818
#
#    positive  negative  neutral
# 0     0.055     0.000    0.945
# 1     0.100     0.000    0.900
# 2     0.085     0.000    0.915
# 3     0.000     0.055    0.945
# 4     0.000     0.066    0.934

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  97.000000  97.000000  97.000000  97.000000
# mean    0.147958   0.062175   0.040588   0.897258
# std     0.437711   0.052976   0.055504   0.076157
# min    -0.831600   0.000000   0.000000   0.640000
# 25%    -0.077200   0.000000   0.000000   0.851000
# 50%     0.202300   0.066000   0.000000   0.926000
# 75%     0.507000   0.088000   0.069000   0.945000
# max     0.914100   0.249000   0.271000   1.000000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  95.000000  95.000000  95.000000  95.000000
# mean    0.164709   0.054232   0.026737   0.919032
# std     0.401096   0.053027   0.049022   0.070793
# min    -0.877900   0.000000   0.000000   0.551000
# 25%     0.000000   0.000000   0.000000   0.893000
# 50%     0.250000   0.057000   0.000000   0.934000
# 75%     0.468400   0.089000   0.045500   0.956500
# max     0.757900   0.239000   0.287000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum had a larger mean positive score but the difference was very marginal.
#
# Q: Which coin had the highest compound score?
#
# A: On this day Ethereum had a higher compound score. This could be because Bitcoin has a significant drop in price the day previous to me running the query for headlines
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin had a highest postitive score of .249 comapred to Ethereum's highest postive score of .239

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Expand the default stopwords list if necessary

sw_addon = {'ha', 'char', 'every', 'has', 'have', 'had', 'colleague'}

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
    words = word_tokenize(re_clean)
    # Lemmatize Words into root words
    lemmatizer = WordNetLemmatizer() 
    lem = [lemmatizer.lemmatize(word) for word in words]
    #convert to lower and remove the stopwords 
    tokens = [word.lower() for word in lem if word.lower() not in sw.union(sw_addon)]
            
    return tokens

# %%
bitcoin_tokens = bitcoin_df.copy()

# %%
tokenized = []
for i in bitcoin_tokens['text']:
    tokenized_articles = tokenizer(i)
    tokenized.append({'tokens':tokenized_articles})

# %%
tokens_df= pd.DataFrame(tokenized)
bitcoin_tokens['tokens_text'] = tokens_df
bitcoin_tokens.head()
# Out:
#          date                                               text  compound  \
# 0  2019-11-03  Less than two miles from Icelands Reykjavik ai...   -0.1531
# 1  2019-11-20  Whether Bitcoin, an immaterial resource derive...    0.2999
# 2  2019-11-01  High school students in France may be among th...    0.0000
# 3  2019-10-27  Our robot colleague Satoshi Nakaboto writes ab...    0.5070
# 4  2019-11-08  Our robot colleague Satoshi Nakaboto writes ab...    0.5070
#
#    positive  negative  neutral  \
# 0     0.000     0.039    0.961
# 1     0.104     0.100    0.796
# 2     0.000     0.000    1.000
# 3     0.069     0.000    0.931
# 4     0.067     0.000    0.933
#
#                                          tokens_text
# 0  [less, two, mile, icelands, reykjavik, airport...
# 1  [whether, bitcoin, immaterial, resource, deriv...
# 2  [high, school, student, france, may, among, fi...
# 3  [robot, satoshi, nakaboto, writes, bitcoin, fu...
# 4  [robot, satoshi, nakaboto, writes, bitcoin, bt...

# %%
# Create a new tokens column for ethereum
ethereum_tokens = ethereum_df.copy()

# %%
tokenized_eth = []
for i in ethereum_tokens['text']:
    tokenized_articles = tokenizer(i)
    tokenized_eth.append({'tokens_text':tokenized_articles})

# %%
tokens_df_eth = pd.DataFrame(tokenized_eth)
ethereum_tokens['tokens_text'] = tokens_df_eth

# %%
ethereum_tokens.head()
# Out:
#          date                                               text  compound  \
# 0  2019-11-20  Sharding and scalability. Transactions per sec...    0.3595
# 1  2019-10-24  Disrupt Berlin is right around the corner. And...    0.6249
# 2  2019-10-23  he plaBy now, you should almost certainly know...    0.4601
# 3  2019-11-01  Blockchain has been picking up the pace since ...   -0.3089
# 4  2019-10-23  Reuters\r\n<ul><li>Bitcoin slumped as much as ...   -0.3818
#
#    positive  negative  neutral  \
# 0     0.055     0.000    0.945
# 1     0.100     0.000    0.900
# 2     0.085     0.000    0.915
# 3     0.000     0.055    0.945
# 4     0.000     0.066    0.934
#
#                                          tokens_text
# 0  [sharding, scalability, transactions, per, sec...
# 1  [disrupt, berlin, right, around, corner, plent...
# 2  [plaby, almost, certainly, know, ethereum, eth...
# 3  [blockchain, picking, pace, since, inception, ...
# 4  [reutersullibitcoin, slumped, much, wednesday,...

# %% [markdown]
# ---

# %% [markdown]
# # NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
all_bitcoin_words = []
for text in bitcoin_tokens['tokens_text']:
    for word in text:
        all_bitcoin_words.append(word)

# %%
all_eth_words = []
for text in ethereum_tokens['tokens_text']:
    for word in text:
        all_eth_words.append(word)

# %%
bitcoin_sent = []
for sent in bitcoin_tokens['text']:
    sent_list = sent
    bitcoin_sent.append(sent_list)

# %%
eth_sent = []
for sent in ethereum_tokens['text']:
    sent_list_eth = sent
    eth_sent.append(sent_list_eth)

# %%
# Generate the Bitcoin N-grams where N=2
def bigram_counter(corpus): 
    # Combine all articles in corpus into one large string
    big_string = ' '.join(corpus)
    processed = tokenizer(big_string)
    bigrams = ngrams(processed, n=2)
    top_15 = dict(Counter(bigrams).most_common(10))
    return pd.DataFrame(list(top_15.items()), columns=['Bigram', 'Count'])

# %%
bigram_counter(bitcoin_sent)
# Out:
#                   Bigram  Count
# 0    (satoshi, nakaboto)     36
# 1         (bitcoin, btc)     25
# 2       (robot, satoshi)     18
# 3     (nakaboto, writes)     18
# 4      (writes, bitcoin)     18
# 5  (fucking, daywelcome)     18
# 6  (daywelcome, another)     18
# 7     (another, edition)     18
# 8     (edition, bitcoin)     18
# 9       (bitcoin, today)     18

# %%
# Generate the Ethereum N-grams where N=2
bigram_counter(eth_sent)
# Out:
#                      Bigram  Count
# 0          (early, morning)     11
# 1         (ethereum, ended)     10
# 2           (saw, ethereum)      9
# 3       (morning, intraday)      9
# 4              (ended, day)      9
# 5              (start, day)      8
# 6                (day, saw)      8
# 7          (intraday, high)      7
# 8           (price, action)      5
# 9  (ethereumethereum, fell)      5

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    Counter_words = dict(Counter(tokens).most_common(N))
    return pd.DataFrame(list(Counter_words.items()), columns=['Word', 'Count'])

# %%
# Get the top 10 words for Bitcoin
token_count(all_bitcoin_words)
# Out:
#              Word  Count
# 0         bitcoin     95
# 1         satoshi     39
# 2        nakaboto     36
# 3  cryptocurrency     30
# 4             btc     27
# 5            past     21
# 6             say     21
# 7         another     20
# 8           today     20
# 9          writes     19

# %%
# Get the top 10 words for Ethereum
token_count(all_eth_words)
# Out:
#              Word  Count
# 0        ethereum     65
# 1      blockchain     27
# 2             day     26
# 3         bitcoin     24
# 4  cryptocurrency     19
# 5         morning     16
# 6           price     14
# 7            week     13
# 8           early     12
# 9         startup     11

# %% [markdown]
# # Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
def processed_text(corpus): 
    # Combine all articles in corpus into one large string
    big_string = ' '.join(corpus)
    return big_string

# %%
bitcoin_words = processed_text(all_bitcoin_words)
eth_words = processed_text(all_eth_words)

# %%
wc = WordCloud(collocations=False).generate(bitcoin_words)
fig = plt.figure()
plt.imshow(wc)
plt.show()

# %%
fig = plt.figure()
wc = WordCloud().generate(eth_words)
plt.imshow(wc)
plt.show()

# %% [markdown]
# # Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both coins and visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
# Concatenate all of the bitcoin text together
bitcoin_sent = []
for sent in bitcoin_tokens['text']:
    sent_list = sent
    bitcoin_sent.append(sent_list)
    
big_string_bitcoin = ' '.join(bitcoin_sent)

# %%
bitcoin_doc = nlp(big_string_bitcoin)
bitcoin_doc.user_data['title'] = 'Bitcoin Name Entity Recognition'
displacy.render(bitcoin_doc, style='ent')
# Out:
# <h2 style="margin: 0">Bitcoin Name Entity Recognition</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Less than two miles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  from
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Icelands Reykjavik
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  airport sits a nondescript metal building as monolithic and drab as a commercial poultry barn. Theres a deafening racket inside, too, but it doesnt come from clucking chickens. Instead,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tens of thousands
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of whirring… [+3426 chars] Whether
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , an immaterial resource derived from hype and blind faith, will vanish into thin air is uncertain, but it will leave behind a dark cloud of carbon pollution. Cryptocurrency mining facilities use so much energy that the government of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Abkhazia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  c… [+3402 chars] High school students in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  may be among the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# </br>The Next Web reports that the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     French
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  education ministry,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Le Ministère de lÉducation Nationale
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , will integrate cryptocurrency into its … [+1439 chars] Our robot colleague
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Satoshi Nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  writes about
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>Welcome to another edition of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , where I,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Satoshi Nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , tell you whats been going on with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past 24 hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# . As
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Baudriallard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  used to say: Theres
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     only one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  … [+3093 chars] Our robot colleague
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Satoshi Nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  writes about
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>Welcome to another edition of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</spa

# %%
# Run the NER processor on all of the text

# Add a title to the document

# %%
# Render the visualization
# Out:
# <h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Cryptocurrency exchange
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Binance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has resumed trading activity. Users can now cancel open orders, deposit crypto assets into their
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Binance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  account, and of course buy and sell cryptocurrencies. You cant withdraw crypto assets to an external wallet just yet, but … [+1191 chars]Bitcoin is now trading at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     around $8,130
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# , up a whopping
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     60.84 percent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the past month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , with the price surging $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     3,086.14
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>The cryptocurrency’s meteoric rise is reminiscent of its rocketing growth in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the latter half of 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , when prices reac… [+4311 chars]Binance has vowed to raise the quality of its security in the aftermath of a hack that saw thieves make off with over
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     $40 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>The company — which is widely believed to operate the world’s largest crypto exchange based on tra… [+2269 chars]A new payment network called
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Flexa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is launching
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that’ll let you spend cryptocurrencies in physical stores. The technology currently supports bitcoin, ether, bitcoin cash, and the gemini dollar, and it’ll work at retailers including
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     GameStop
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Nordstrom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# , … [+1743 chars]If you thought that the theft of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     7,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  bitcoins from one of the world's biggest crypto exchanges would stop
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>On
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the price of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  went above $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin:

# %%
# List all Entities
for ent in bitcoin_doc.ents:
    print (ent, ent.label_)
# Out:
# Less than two miles QUANTITY
# Icelands Reykjavik FAC
# tens of thousands CARDINAL
# Bitcoin GPE
# Abkhazia GPE
# France GPE
# first ORDINAL
# French NORP
# Le Ministère de lÉducation Nationale ORG
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Baudriallard PERSON
# only one CARDINAL
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Isaac Newton PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Machiavelli PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Nietzsche PERSON
# Time ORG
# Jack Dorsey PERSON
# Bitcoin GPE
# Ghana GPE
# just weeks DATE
# Dorsey PERSON
# Bitcoin GPE
# Africa LOC
# Nigeria GPE
# Ghana GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Hegel PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Isaac Newton PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Sloterdijk PERSON
# November
# 8, 2019 DATE
# 6 min QUANTITY
# this decade DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Jane Didion PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Kierkegaard PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Planck PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Bentham PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Descartes PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Nikola Tesla ORG
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Habermass PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Bentham PERSON
# Crack PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Satoshi Nakamoto PERSON
# Last summer DATE
# Bitcoin GPE
# NYC ORG
# Bitcoin GPE
# ofPokémon Go PERSON
# Bitcoin NORP
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Satoshi Nakamoto PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Rousseau PERSON
# Bitcoin BTC FAC
# Eurasian NORP
# Georgia GPE
# BBC ORG
# Business Daily ORG
# Georgia GPE
# third ORDINAL
# Bitcoin GPE
# 2013 DATE
# Luka_Magnotta ORG
# the year 2025 DATE
# +3096 ORG
# MEXICO CITY/ GPE
# WASHINGTON GPE
# Reuters ORG
# about $5 million MONEY
# bitcoin GPE
# Mexico GPE
# Pemex ORG
# Reuters ORG
# Tuesday DATE
# Bitcoin Cash BCH PERSON
# five CARDINAL
# Bitcoin Cash PERSON
# August 2017 DATE
# Chinese NORP
# Xi Jinping PERSON
# the Political Bureau of the Central Committee ORG
# the Communist Party ORG
# Bitcoin GPE
# Communist NORP
# Party ORG
# Bitcoin GPE
# English NORP
# Premier League ORG
# Bitcoin BTC ORG
# Yesterday DATE
# Wolverhampton Wanderers FC ORG
# Bitcoin NORP
# Australia GPE
# one CARDINAL
# twenty-fold CARDINAL
# Jack Dorsey PERSON
# Facebooks Libra ORG
# Dorsey PERSON
# Bitcoin GPE
# CoinLists ORG
# $10 million MONEY
# million CARDINAL
# 1,457% PERCENT
# the past four years DATE
# Indeed.com ORG
# first ORDINAL
# Morning TIME
# November DATE
# Lets PERSON
# 1 CARDINAL
# +2612 ORG
# the Ukranian Railways ORG
# Bitcoin GPE
# more than $40,000 MONEY
# Ukrzaliznytsia PERSON
# 8,000 CARDINAL
# BTC ORG
# $15.5 million MONEY
# Bitcoin News ORG
# Earlier this year DATE
# Mornings TIME
# Hard Forks PERSON
# 1 CARDINAL
# Blockchain GPE
# Swiss NORP
# Swiss NORP
# Block PERSON
# English LANGUAGE
# the UK Jurisdiction Taskforce of ORG
# the Lawtech Deliver Panel ORG
# today DATE
# Bitcoin GPE
# the year DATE
# 148 MONEY
# Italy GPE
# Ferrari ORG
# Tuscan NORP
# Bitcoin PERSON
# Italians NORP
# Reuters
#  ORG
# Bitcoin PERSON
# as much as 9% PERCENT
# Wednesday DATE
# June DATE
# Facebook ORG
# Mark Zuckerberg's PERSON
# Libra GPE
# Zuckerberg PERSON
# $400 million MONEY
# Ripple XRP PERSON
# XRP ORG
# Ponzi PERSON
# XRP ORG
# London GPE
# less than 0.2 percent PERCENT
# XRP ORG
# Facebooks Libra PERSON
# Mark Zuckerberg PERSON
# SIM ORG
# Gregg Bennett PERSON
# Bittrex ORG
# nearly $1 million MONEY
# Bitcoin GPE
# BTCCoinDesk PERSON
# last week DATE
# Bittrex ORG
# Uber PERSON
# Bitcoin GPE
# two CARDINAL
# Uber PRODUCT
# LinkedIn ORG
# This week DATE
# WhatsApp ORG
# Facebook ORG
# Israeli NORP
# NSO G ORG
# last year DATE
# Bitcoins 2017 EVENT
# One CARDINAL
# Bitfinex PERSON
# Eleven years ago DATE
# Satoshi Nakamoto ORG
# Bloomberg ORG
# Next Africa GPE
# Bloomberg Africa ORG
# The City of Johannesburg GPE
# four CARDINAL
# Ripple XRP PERSON
# XRP ORG
# Bitcoin GPE
# XRP PERSON
# third ORDINAL
# Bakkt PERSON
# the Bitcoin Futures Trading ORG
# Digital Assets ORG
# BTC ORG
# Kelly Loeffler PERSON
# Bitcoin GPE
# this past July DATE
# Days later DATE
# September DATE
# nearly 25 percent PERCENT
# Iranian NORP
# Bitcoin BTC FAC
# Irans Energy Ministry ORG
# U.S. GPE
# Thursday DATE
# +2653 WORK_OF_ART
# PayPal ORG
# Bank of America ORG
# cryptocurrencies.</li><li ORG
# Roelof Botha PERSON
# Sequoia Capital a… ORG
# Brian Ach/Getty PERSON
# PayPal ORG
# Bank of America ORG
# cryptocurrencies.</li><li ORG
# Roelof Botha PERSON
# below $7,500 MONEY
# first ORDINAL
# May DATE
# Bitcoin BTC ORG
# between one and three months DATE
# +1846 ORG
# Big Brother ORG
# John de Mol PERSON
# Facebook PERSON
# Dutch NORP
# Bitcoin NORP
# Reuters ORG
# Aestetix ORG
# Planet Earth LOC
# NYC ORG
# 2600 CARDINAL
# 2020 DATE
# several months DATE
# Australian NORP
# Reuters ORG
# Jonathan Ernst
#  PERSON
# China GPE
# US GPE
# Gao Feng PERSON
# Mexican NORP
# Ovidio Guzman Lopez PERSON
# Mexican NORP
# El Chapo PERSON
# Joaquin Archivaldo Guzman Loera PERSON
# Sinaloa PERSON
# +1541 ORG
# Zimbabwean NORP
# Tawanda Kembo PERSON
# Golix ORG
# ZDNet ORG
# one CARDINAL
# today DATE
# Link11 PERSON
# two CARDINAL
# RDOS ORG
# the past years DATE
# China GPE
# blockchain GPE
# China GPE
# blockchain GPE
# Li Wei PERSON
# Blockchain GPE
# the year 2009 DATE
# Santoshi Nakamoto PERSON
# Nakamoto ORG
# Bitcoin PERSON
# Blockchai GPE
# +9390 ORG
# million CARDINAL
# eight-year DATE
# 2007 DATE
# 2015 DATE
# Australian NORP
# 15,370 CARDINAL
# Jack Dorsey PERSON
# Facebooks ORG
# New York City GPE
# yesterday DATE
# Dorsey ORG
# Libra GPE
# US GPE
# Russian NORP
# The Moscow Times ORG
# the Nadvoitsy Aluminum Plant ORG
# Russian NORP
# Rusal PRODUCT
# FOMO LAW
# Bitcoin GPE
# BTC ORG
# Bloomberg ORG
# BTC ORG
# the spring of 2017 DATE
# the last three months of 2017 DATE
# Dutch NORP
# Facebook PERSON
# John de Mol PERSON
# Du PERSON
# Ethereums PRODUCT
# two CARDINAL
# November
# 12, 2019 DATE
# 5 min QUANTITY
# first ORDINAL
# Bitcoin GPE
# blockchain GPE
# another week DATE
# the week DATE
# the weekend DATE
# 1 CARDINAL
# BBC ORG
# Russia GPE
# British Columbia GPE
# Canada GPE
# Bitcoin GPE
# 7500 MONEY
# 10300 MONEY
# October 25th 2019 DATE
# Bitcoin GPE
# Cypher PERSON
# Yannitell ORG
# 2006 DATE
# Haas ORG
# Opera PERSON
# one CARDINAL
# Opera Mobile ORG
# second ORDINAL
# the Starship Blockchain LOC
# The US Department of Justice ORG
# 337 CARDINAL
# at least 18 CARDINAL
# One year ago DATE
# first ORDINAL
# Tether PERSON
# A year later DATE
# last month DATE
# versus iFinex et al. PERSON
# US GPE
# District Court ORG
# Picasso PERSON
# The Royal Bank of Canada ORG
# Last week DATE
# Canadian NORP
# The Logic WORK_OF_ART
# The Royal Bank of Canada ORG
# Tomorrow DATE
# Architecture WORK_OF_ART
# Edwina Attlee PERSON
# Phineas Harper PERSON
# Maria Smith PERSON
# the Oslo Architecture Triennale ORG
# Bitcoin GPE
# Wednesday DATE
# Facebook Inc.s ORG
# Mark Zuckerberg PERSON
# Libra GPE
# Zuckerberg PERSON
# Stephen Shankland PERSON
# four years DATE
# 1.0 CARDINAL
# earlier this year DATE
# Bitmain Technologies ORG
# US GPE
# US GPE
# +1280 GPE
# Mt. Goxs PRODUCT
# +1073 PRODUCT
# CNET ORG
# Windows 7 PRODUCT
# January DATE
# Windows 10 FAC
# Microsoft ORG
# Tuesday DATE
# China GPE
# the weekend DATE
# January 1, 2020 DATE
# +3204 ORG
# November
# 20, 2019 DATE
# 4 min QUANTITY
# Crypto NORP

# %% [markdown]
# ---

# %% [markdown]
# ## Ethereum NER

# %%
# Concatenate all of the bitcoin text together
eth_sent = []
for sent in ethereum_tokens['text']:
    sent_list_eth = sent
    eth_sent.append(sent_list_eth)
    
big_string_eth = " ".join(eth_sent)

# %%
# Run the NER processor on all of the text

eth_doc = nlp(big_string_eth)
eth_doc.user_data['title'] = 'Ethereum Named Entity Recogition'
displacy.render(eth_doc, style='ent')
# Out:
# <h2 style="margin: 0">Ethereum Named Entity Recogition</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Sharding and scalability. Transactions per
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# .  Crypto-ecosystems. The decentralized web. These are the voyages of
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Starship Blockchain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , on its 5-year mission to seek out Ok, you get the drift! But as you can tell, there remain many, many issues to tea… [+3851 chars]
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Disrupt Berlin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Join us
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     December 11 and December 12
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to hear from industry leaders, investors, and bright stars in the startup world. We’ll sit down with CEOs from big-name companies such as A… [+14834 chars] he plaBy now, you should almost certainly know about Ethereum,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ETH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# </br>Ethereums creators wanted to build a platform that would allow users all over the world to write … [+7608 chars]
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Blockchain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has been picking up the pace since its inception in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the year 2009
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  by a pseudo group named as
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Santoshi Nakamoto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nakamoto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has released a whitepaper named as
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# : A peer-to-peer electronic cash system which never clearly mentioned about
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Blockchai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# … [
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     +9390
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  chars]
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# &lt;ul&gt;&lt;li&gt;
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  slumped
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     as much as 9%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  — hitting its lowest level since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  — ahead of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Facebook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  CEO
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mark Zuckerberg's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  testimonial on the company's proposed cryptocurrency,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Libra
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; ve

# %%
# Render the visualization
# Out:
# <h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  tweeted insults at
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  again
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     this morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , but this time
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Jack
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  took the conversation off platform to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the White House
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . In other news, a controversial Census question creates some strange bedfellows, and a &quot;blockchain bandit&quot; is pilfering mil… [+1705 chars]After announcing that they were launching a managed blockchain service
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     late last year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Amazon Web Services
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>It was
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     only about five months ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that AWS chief executive
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Andy Jassy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  announced that the compa… [+1220 chars]Captain
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Kirk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     neo-Dadaists
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# . Repugnant markets and legendary cryptographers. “
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Digital
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  couture” auctioned by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     CryptoKitties
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  developers. Distributed autonomous art organizations. A keynote speech looking back from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2047
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  at the near-apocalypse of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2026
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , from whic… [+5265 chars]So long as cryptocurrency exists, so too will the extraordinarylengths to which thieves will go to try to steal it. Unfortunately, that also includes preying on weak private keys, a method that has evidently made
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  crypto bandit filthy rich with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     millions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  in… [+2703 chars]If you thought that the theft of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     7,000
#     <span styl

# %%
# List all Entities
for ent in eth_doc.ents:
    print (ent, ent.label_)
# Out:
# second ORDINAL
# the Starship Blockchain LOC
# Disrupt Berlin PERSON
# December 11 and December 12 DATE
# ETH ORG
# second ORDINAL
# Blockchain GPE
# the year 2009 DATE
# Santoshi Nakamoto PERSON
# Nakamoto ORG
# Bitcoin PERSON
# Blockchai GPE
# +9390 ORG
# Reuters
#  ORG
# Bitcoin PERSON
# as much as 9% PERCENT
# Wednesday DATE
# June DATE
# Facebook ORG
# Mark Zuckerberg's PERSON
# Libra GPE
# Zuckerberg PERSON
# Swiss NORP
# Swiss NORP
# Block PERSON
# $400 million MONEY
# Ripple XRP PERSON
# XRP ORG
# Ponzi PERSON
# XRP ORG
# London GPE
# less than 0.2 percent PERCENT
# XRP ORG
# The Royal Bank of Canada ORG
# Last week DATE
# Canadian NORP
# The Logic WORK_OF_ART
# The Royal Bank of Canada ORG
# Opera PERSON
# one CARDINAL
# Opera Mobile ORG
# the day DATE
# six CARDINAL
# Ripple XRP PERSON
# XRP ORG
# Bitcoin GPE
# XRP PERSON
# third ORDINAL
# Blockchain GPE
# Bitcoin GPE
# the Complete Blockchain and Ethereum Programmer Bundle ORG
# just $29 MONEY
# Bejing ORG
# first ORDINAL
# public last week DATE
# Chinese NORP
# 2021 DATE
# first ORDINAL
# last year DATE
# Chinese NORP
# Tencent LOC
# blockchain GPE
# Framework of DL PERSON
# November
# 20, 2019 DATE
# 4 min QUANTITY
# Crypto NORP
# British Columbia GPE
# Canada GPE
# second ORDINAL
# the Starship Blockchain LOC
# a gray morning TIME
# May 2016 DATE
# San Francisco GPE
# Montgomery Street FAC
# Wells Fargo ORG
# two CARDINAL
# The Complete Blockchain &amp ORG
# Ethereum Programmer Bundle ORG
# ten CARDINAL
# November
# 12, 2019 DATE
# 5 min QUANTITY
# first ORDINAL
# Bitcoin GPE
# Bitcoin GPE
# Facebook ORG
# Libra GPE
# don PERSON
# 2 CARDINAL
# Takeaway PERSON
# CFTC ORG
# Heath Tarbert PERSON
# last month DATE
# U.S. GPE
# the next six months.</li><li DATE
# Bitcoin GPE
# BTC/USD ORG
# ETH/USD ORG
# 2.70% PERCENT
# Monday DATE
# ETH/USD ORG
# Besu PRODUCT
# Hyperledger ORG
# Linux CARDINAL
# Getty
#  ORG
# 2.0 CARDINAL
# Just a couple of weeks ago TIME
# DevCon 5 PRODUCT
# Tokyo GPE
# Bitcoin GPE
# the year DATE
# 148 MONEY
# J. Christopher Giancarlo PERSON
# the Commodity Futures Trading Commission ORG
# CFTC ORG
# Senate ORG
# February 2018 DATE
# Bloomberg Finance LP ORG
# Andrew Harrer PERSON
# million CARDINAL
# 1,457% PERCENT
# the past four years DATE
# Indeed.com ORG
# Digital ORG
# Webjet ORG
# Microsoft ORG
# 2016 DATE
# Webjet ORG
# UNICEF ORG
# the Ethereum Foundation ORG
# Devcon PERSON
# UNICEF ORG
# Takeaway ORG
# Ethereum 2.0 FAC
# the early months DATE
# years DATE
# The Takeaway
#  ORG
# 2.0 CARDINAL
# 4.610.3 percent PERCENT
# start.</li><li PRODUCT
# 2.0 CARDINAL
# Commodity Futures Trading Commission ORG
# CFTC ORG
# Heath Tarbert PERSON
# 2020 DATE
# Georgetown University ORG
# the first day of DC Fintech Week DATE
# Tarbert PERSON
# Canadian NORP
# Ledn PERSON
# DAI ORG
# Ledn co- PERSON
# Mauricio Di Bartolomeo PERSON
# Venezuelan NORP
# CoinDesk PERSON
# up to $10 million MONEY
# 0.83% PERCENT
# Sunday DATE
# 0.01% PERCENT
# Saturday DATE
# the week DATE
# 1.41% PERCENT
# 181.73 MONEY
# the day DATE
# an early morning TIME
# 185.00 MONEY
# 2.49% PERCENT
# Monday DATE
# 0.83% PERCENT
# Sunday DATE
# the day DATE
# 186.25 MONEY
# the day DATE
# 180.45 MONEY
# first ORDINAL
# 3.28% PERCENT
# Monday DATE
# 2.65% PERCENT
# last week DATE
# the day DATE
# 177.85 MONEY
# the day DATE
# an early morning TIME
# 183.95 MONEY
# 182.18 MONEY
# Bitcoin GPE
# BTC/USD ORG
# 9200 MONEY
# Bitcoin GPE
# Thursday DATE
# some 1.5% PERCENT
# second ORDINAL
# Bitcoin GPE
# BTC/USD ORG
# Bitcoin GPE
# some 1.30% PERCENT
# the second half DATE
# ConsenSys ORG
# Joe Lubin PERSON
# Forbes PERSON
# Timothy Archibald
#  PERSON
# Joe Lubin PERSON
# Vitalik Buterin PERSON
# ConsenSys ORG
# Ethereum
#  ORG
# 2.24% PERCENT
# Monday DATE
# 2.22% PERCENT
# Sunday DATE
# the day DATE
# 184.65 MONEY
# the day DATE
# an early morning TIME
# 190 MONEY
# first ORDINAL
# Takeaway NORP
# CFTC ORG
# Heath Tarbert PERSON
# last month DATE
# U.S. GPE
# the next six months DATE
# Getty
#  PERSON
# 30 CARDINAL
# Detroit GPE
# last weekend DATE
# the Mobility Open Blockchain Initiative EVENT
# MOBI ORG
# Today DATE
# 98% PERCENT
# this Complete Blockchain &amp ORG
# Ethereum Programmer Bundle ORG
# ten CARDINAL
# Bitcoin GPE
# S3studio/Getty Images ORG
# 2018 DATE
# Bitcoin GPE
# this week DATE
# 1,000 MONEY
# a few days ago DATE
# earlier today TIME
# over $9,000 MONEY
# almost $7,000 MONEY
# Lightning GPE
# Radar Relay PERSON
# DEX PERSON
# RedShift ORG
# Microsoft ORG
# Satya Nadella PERSON
# Microsoft ORG
# Azure Clo PRODUCT
# Adam Back PERSON
# Blockstream Corp. ORG
# Group ORG
# Our Future in the Digital Age WORK_OF_ART
# G20 ORG
# Libra GPE
# Facebooks NORP
# Ripple PERSON
# Brad Garlinghouse PERSON
# Joe Lubin PERSON
# Wednesday DATE
# Lubin PERSON
# Libra GPE
# Facebook ORG
# Ethereums PRODUCT
# Istanbul GPE
# the week of Dec. 4 DATE
# Oct. 25 DATE
# Friday DATE
# Danno Ferrin PERSON
# studi NORP
# Storj Labs ORG
# Tuesday DATE
# the day ahead DATE
# through to $182 MONEY
# 184.78 MONEY
# the morning TIME
# 181.95 MONEY
# +1834 ORG
# Noelle Acheson PERSON
# CoinDesks Director of Research ORG
# Institutional Crypto GPE
# CoinDesk PERSON
# weekly DATE
# inst ORG
# two CARDINAL
# dApps ORG
# +5417 ORG
# French NORP
# AXA ORG
# second ORDINAL
# AXA ORG
# British NORP
# Standard Chartered ORG
# over $685 billion MONEY
# the Enterprise Ethereum Alliance ORG
# Alliance ORG
# Standard Chartered ORG
# +1002 ORG
# Digital ORG
# Webjet ORG
# Microsoft ORG
# 2016 DATE
# Webjet ORG
# Aragon ORG
# Ehereum ORG
# Nov. 2 DATE
# Samsung d'light PERSON
# Justin Sun PERSON
# Tron PERSON
# Samsungs Blockchain GPE
# first ORDINAL
# Satoshi PERSON
# Bitcoin GPE
# 1.75% PERCENT
# Tuesday DATE
# 0.64% PERCENT
# Monday DATE
# the day DATE
# 171.3 MONEY
# the day DATE
# an early morning TIME
# 175.4 MONEY
# Ethereum
#  ORG
# 1.25% PERCENT
# Monday DATE
# 2.44% PERCENT
# Sunday DATE
# the day DATE
# 182.02 MONEY
# morning TIME
# an early morning TIME
# 190 MONEY
# +4659 ORG
# Ethereum
#  ORG
# 5.12% PERCENT
# Wednesday DATE
# 1.75% PERCENT
# Tuesday DATE
# the day DATE
# 162.49 MONEY
# the day DATE
# an early morning TIME
# 171.48 MONEY
# 164.10 MONEY
# 4.98% PERCENT
# Tuesday DATE
# 1.25% PERCENT
# Monday DATE
# the day DATE
# 191.1 MONEY
# the day DATE
# an early morning TIME
# 181.72 MONEY
# 189.19 MONEY
# Splunk GPE
# 40,000 MONEY
# 10,000 CARDINAL
# annual DATE
# Las Vegas GPE
# last week DATE
# Commodity Futures Trading Commission ORG
# CFTC ORG
# Heath Tarbert PERSON
# 2020 DATE
# Georgetown University ORG
# the first day of DC Fintech Week DATE
# Tarbert PERSON
# 0.64% PERCENT
# Monday DATE
# 2% PERCENT
# Sunday DATE
# the day DATE
# 174.37 MONEY
# the day DATE
# mid-morning TIME
# 173.41 MONEY
# late morning TIME
# 178 MONEY
# Ethereum
#  ORG
# 4% PERCENT
# Wednesday DATE
# 4.98% PERCENT
# Tuesday DATE
# the day DATE
# 183.38 MONEY
# the day DATE
# an early morning TIME
# 192.2 MONEY
# +4168 PRODUCT
# Kenneth Blanco PERSON
# the Financial Crimes Enforcement Network ORG
# Treasury ORG
# Monday DATE
# 2019/08/30 CARDINAL
# Bitcoin GPE
# Avishek Das PERSON
# Getty Images)
#  ORG
# Wednesday DATE
# HODLers NORP
# Bitcoin GPE
# Ethereums PRODUCT
# Istanbul GPE
# the week of Dec. 4 DATE
# Oct. 25 DATE
# Friday DATE
# Danno Ferrin PERSON
# studi NORP
# Lightning NORP
# Radar Relay PERSON
# DEX PERSON
# RedShift ORG
# Blockchain GPE
# Bitcoin GPE
# Ethereum PERSON
# DeFi PERSON
# Storj Labs PERSON
# Tuesday DATE
# SJCX NORP
# Counterparty NORP
# 184.19 MONEY
# 192.78 MONEY
# 23.6% PERCENT
# 257 MONEY
# 38.2% PERCENT
# 367 MONEY
# 62% PERCENT
# 543 MONEY
# Stellar NORP
# Lumen
# Stellar ORG
# 8% PERCENT
# Sunday DATE
# Knabu PERSON
# Factom PERSON
# CoinDesk ORG
# London GPE
# today DATE
# Knabu PERSON
# LONDON GPE
# Reuters ORG
# Facebook ORG
# Libra ORG
# Microsoft ORG
# Marley Gray PERSON
# Microsoft ORG
# Monday DATE
# the Azure Blockchain Tokens ORG
# the past few weeks DATE
# ETH ORG
# Bitcoin GPE
# BTC ORG
# $162 and $153 MONEY
# daily DATE
# weekly DATE
# Ether PERSON
# This week DATE
# first ORDINAL
# Multi-Collateral Dai ORG
# range.</li><li>Bitcoin ORG
# analyst.</li><li PRODUCT
# XRP EVENT
# Spanish NORP
# AlyCoin PRODUCT
# Nov. 18 DATE
# the Comisión Nacional del Mercado de Valores ORG
# AlyCoin ORG
# the Maker Foundation ORG
# Wednesday DATE
# roughly $100 million MONEY
# DAI ORG
# more than $339 million MONEY
# Thursday DATE
# the Maker Foundatio PERSON
# PoS ORG
# today DATE
# Thursday DATE
# Amun AG ORG
# Amun Tezos ORG
# the Ethereum (ETH) Foundation Péter Szilágyi ORG
# Dec. 4 DATE
# Istanbul GPE
# two CARDINAL
# Nov. 7 DATE
# Szilágyi PERSON
# Istanbul GPE
# 9069000 CARDINAL
# Blockchain GPE
# ConsenSys ORG
# Trusat ORG
# the Ethereum (ETH ORG
# Oct. 22 DATE
# Trusat PERSON
# blockchain GPE
# ConsenSys ORG
# Joseph Lubin PERSON
# Bitcoin Technical Analysis ORG
# 9100 MONEY
# Bitcoin GPE
# some 1.45% PERCENT
# the second half DATE
# Blockchain GPE
# Gods Unchained LOC
# CryptoKitties ORG
# a matter of days DATE
# Gods Unchained LOC
# Noelle Acheson PERSON
# CoinDesks Director of Research ORG
# Institutional Crypto GPE
# CoinDesk PERSON
# weekly DATE
# inst ORG
# Bitski PERSON
# $1.8 MONEY
# Galaxy Digital ORG
# Winklevoss Capital GPE
